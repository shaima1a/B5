# %% [markdown]
# # Visualization Exercises

# %% [markdown]
# ## Name: Shaima Alqahtani

# %% [markdown]
# ### 1. Antibiotic use in children
#
# The bar plot and the pie chart below show the distribution of pre-existing medical conditions of children involved in a study on the optimal duration of antibiotic use in treatment of tracheitis, which is an upper respiratory infection.

# %% [markdown]
# ![](../../assets/viz_exercise_1.png)

# %% [markdown]
# a. What features are apparent in the bar plot but not in the pie chart?
#
# b. What features are apparent in the pie chart but not in the bar plot?
#
# c. Which graph would you prefer to use for displaying these categorical data?

# %% [markdown]
# ## a:
# - Exact counts or relative magnitudes — you can see how many children had each condition or compare the heights directly.
#
# - Ease of comparing categories — small differences between conditions are clearer in bars than in slices.
#
# - Potential for additional variables — bars can show grouped or stacked data (e.g., by age or gender), which a pie chart cannot.
#
# - Visibility of minor categories — even rare conditions remain visible as short bars, whereas tiny slices may be hard to see.

# %% [markdown]
# ## b:
# - Overall proportion of each condition — the chart shows how each category contributes to the total population.
#
# - Visual sense of the whole — the circle format intuitively conveys “parts of a whole.”
#
# - Immediate perception of dominance — large slices stand out as major contributors, giving a quick impression of which conditions are most common.

# %% [markdown]
# ## c:
# For this study, the bar plot is generally preferable.
# It allows clearer comparison between categories, handles small differences better, and can easily accommodate additional data dimensions. Pie charts are useful for showing overall proportions but become less effective when there are many categories or small differences.

# %% [markdown]
# ### 2. Black Lives Matter.
#
# A Washington Post-Schar School poll conducted in the United States in June 2020, among a random national sample of 1,006 adults, asked respondents whether they support or oppose protests following George Floyd’s killing that have taken place in cities across the US. The survey also collected information on the age of the respondents. (Washington Post 2020) The results are summarized in the stacked bar plot below.

# %% [markdown]
# ![](../../assets/viz_exercise_3.png)

# %% [markdown]
# a. Based on the stacked bar plot, do views on the protests and age appear to be associated? Explain your reasoning.
#
# b. Conjecture other possible variables that might explain the potential association between these two variables.

# %% [markdown]
# ## a:
# Yes, views on the protests and age do appear to be associated.
#
# From the stacked bar plot, younger age groups (especially 18–29 and 30–39) show higher levels of support (“somewhat support” and “strongly support”) and lower levels of opposition. In contrast, older age groups (especially 65+ and 50–64) show more opposition (“somewhat oppose” and “strongly oppose”) and less strong support.
# Because the proportions of support and opposition change systematically across age groups, this suggests an association between age and views on the protests.

# %% [markdown]
# ## b:
# Possible confounding variables include:
#
# - Education level
#
# - Political ideology
#
# - Income
#
# - Geographic region
#
# - Media exposure

# %% [markdown]
# ### 3. Heart transplant data display.
#
# The Stanford University Heart Transplant Study was conducted to determine whether an experimental heart transplant program increased lifespan. Each patient entering the program was officially designated a heart transplant candidate, meaning that they were gravely ill and might benefit from a new heart. Patients were randomly assigned into treatment and control groups. Patients in the treatment group received a transplant, and those in the control group did not. The visualizations below display two different versions of the study results.9 (Turnbull, Brown, and Hu 1974)

# %% [markdown]
# ![](../../assets/viz_exercise_5.png)

# %% [markdown]
# a. Provide one aspect of the two group comparison that is easier to see from the stacked bar plot (left)?
#
# b. Provide one aspect of the two group comparison that is easeir to see from the standardized bar plot (right)?
#
# c. For the Heart Transplant Study which of those aspects would be more important to display? That is, which bar plot would be better as a data visualization?

# %% [markdown]
# ## a:
# The stacked bar plot makes it easier to see the total number of patients in each group (treatment vs control).
# can clearly compare how many patients were in the treatment group versus the control group, and how many in each group survived or died in absolute numbers.

# %% [markdown]
# ## b:
# The standardized bar plot makes it easier to compare proportions (percent survival) between the two groups.
# It shows what fraction of each group survived or died, regardless of how many people were in each group.

# %% [markdown]
# ## c:
# For this study, the proportion of patients who survived is the most important aspect, because the research question is whether the heart transplant increased survival rate.
# Therefore, the standardized bar plot is the better visualization — it directly compares survival percentages between treatment and control groups.

# %% [markdown]
# ### 4. Meat consumption and life expectancy.
#
# In data collected for You et al. (2022), total meat intake is associated with life expectancy (at birth) in 175 countries. Meat intake is measured in kg per capita per year (averaged over 2011 to 2013). The two ridge plots show an association between income and meat consumption (higher income countries tend to eat more meat) and an association between income and life expectancy (higher income countries have higher life expectancy).

# %% [markdown]
# ![](../../assets/viz_exercise_7.png)

# %% [markdown]
# a. Do the graphs above demonstrate that meat consumption and life expectancy are associated? That is, can you tell if countries with low meat consumption have low life expectancy? Explain.
#
# b. Let’s assume that you had a plot comparing meat consumption and life expectancy, and they do seem associated. Your friend says that the plot shows that high meat consumption leads to a longer life. You correctly say, no, we can’t tell if there is a causal realtionship because the relationship is confounded by income level. Explain what you mean.
#
# c. How can you investigate the relationship between meat consumption and life expectancy in the presence of confounding variables (like income)?

# %% [markdown]
# ## a:
# No, the graphs do not directly show that meat consumption and life expectancy are associated.
# What the graphs show is:
#
# - Higher‑income countries eat more meat.
# - Higher‑income countries have higher life expectancy.
#
# But they do not show meat consumption vs life expectancy on the same plot.
# So we cannot conclude that countries with low meat consumption have low life expectancy based on these two graphs alone.

# %% [markdown]
# ## b:
# Income is a confounding variable because it affects both variables:
#
# Higher income → more meat consumption
#
# Higher income → better healthcare, nutrition, sanitation → longer life expectancy
#
# So even if a plot shows that meat consumption and life expectancy move together, the real reason might be income, not meat.
# This means we cannot claim a causal relationship (meat → longer life) because income influences both.

# %% [markdown]
# ## c:
# To study the relationship between meat consumption and life expectancy while accounting for confounders like income, you can:
#
# - Use multiple regression (include income as a control variable).
#
# - Use stratification: compare countries within the same income group.
#
# - Use partial correlation to measure the relationship after removing the effect of income.
#
# - Use matching: compare countries with similar income levels.
#
# - Use multivariate plots (e.g., scatter plot of meat vs life expectancy, colored by income).
#
# These methods help isolate the effect of meat consumption from the effect of income.
